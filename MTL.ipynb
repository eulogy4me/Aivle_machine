# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
path = "/Users/hongjonghyeok/Downloads/학습데이터_완성본.csv"
df = pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'Latitude', 'Longitude', 'Supply_type',
#        'Applicant_type', 'Units', 'Gender', 'Shared', 'Cutline_rate',
#        'Cutline_score', 'Year', 'Quarter', 'Applied_type', 'Counts_daiso',
#        'Counts_supermarket', 'Counts_laundry', 'Counts_pharmacy',
#        'Counts_cafe', 'Counts_convstore', 'Counts_station', 'Infra_score',
#        'people', 'Rate1', 'Rate2', 'Rate3'],
#       dtype='object')

# %%
df.dropna(axis=0, inplace=True)

# %%
# 주요 입력 변수 및 타겟 변수 선택
features = ['Supply_type', 'Units', 'Gender', 'Year',
            'Quarter', 'Rate1', 'Rate2', 'Rate3']
X = df[features]
y_classification = df['Cutline_rate']  # 분류 타겟
y_regression = df['Cutline_score']    # 회귀 타겟

# %%
X.shape
# Out:
# (876, 8)

# %%
# 범주형 변수 인코딩
X['Supply_type'] = LabelEncoder().fit_transform(X['Supply_type'])
#X['Applicant_type'] = LabelEncoder().fit_transform(X['Applicant_type'])
X['Gender'] = LabelEncoder().fit_transform(X['Gender'])
#X['Applied_type'] = LabelEncoder().fit_transform(X['Applied_type'])
#X['Shared'] = LabelEncoder().fit_transform(X['Shared'])
X['Year'] = LabelEncoder().fit_transform(X['Year'])
X['Quarter'] = LabelEncoder().fit_transform(X['Quarter'])
# Out:
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_18118/788045554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Supply_type'] = LabelEncoder().fit_transform(X['Supply_type'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_18118/788045554.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Gender'] = LabelEncoder().fit_transform(X['Gender'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_18118/788045554.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Year'] = LabelEncoder().fit_transform(X['Year'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_18118/788045554.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Quarter'] = LabelEncoder().fit_transform(X['Quarter'])

# %%
# 데이터 분리
X_train, X_test, y_train_classification, y_test_classification, y_train_regression, y_test_regression = train_test_split(X, y_classification, y_regression, test_size=0.1, random_state=42)

# %%
# 데이터 스케일링
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 레이블 값 변환 (1 → 0, 2 → 1, 3 → 2)
y_train_classification = y_train_classification - 1
y_test_classification = y_test_classification - 1

# %%
X_train.shape
# Out:
# (788, 8)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 입력 레이어
il = Input(shape=(X_train.shape[1],))

# 공유 레이어
dl = Dense(1024, activation='relu')(il)
dl = Dense(1024, activation='relu')(dl)


# 분류 헤드 (cutline_rate)
classification_head = Dense(3, activation='softmax', name='classification')(dl)

# 회귀 헤드 (cutline_score)
regression_head = Dense(1, activation='relu', name='regression')(dl)

# %%
# 모델 정의
model = Model(inputs=il, outputs=[classification_head, regression_head])

# %%
# 모델 컴파일
model.compile(
    optimizer='adam',
    loss={'classification': 'sparse_categorical_crossentropy', 'regression': 'mse'},
    metrics={'classification': 'accuracy', 'regression': 'mae'})

# %%
# EarlyStopping 콜백 정의
es = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 모니터링
    patience=15,              # 개선되지 않는 에포크를 15번 허용
    restore_best_weights=True) # 가장 좋은 가중치를 복원

# %%
checkpoint_path = 'best_model.keras'
mc = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True)

# %%
# 모델 학습
history = model.fit(
    X_train,
    {'classification': y_train_classification, 'regression': y_train_regression},
    validation_data=(X_test, {'classification': y_test_classification, 'regression': y_test_regression}),
    epochs=100,               # 최대 에포크 수
    batch_size=1,
    callbacks=[es, mc]) # EarlyStopping 콜백 추가
# Out:
# Epoch 1/100
# 786/788 [============================>.] - ETA: 0s - loss: 8.7694 - classification_loss: 0.7131 - regression_loss: 8.0563 - classification_accuracy: 0.6934 - regression_mae: 2.2180
# Epoch 1: val_loss improved from inf to 5.53073, saving model to best_model.keras
# 788/788 [==============================] - 2s 2ms/step - loss: 8.7544 - classification_loss: 0.7128 - regression_loss: 8.0416 - classification_accuracy: 0.6942 - regression_mae: 2.2151 - val_loss: 5.5307 - val_classification_loss: 0.6502 - val_regression_loss: 4.8805 - val_classification_accuracy: 0.6818 - val_regression_mae: 1.8509
# Epoch 2/100
# 770/788 [============================>.] - ETA: 0s - loss: 6.7519 - classification_loss: 0.6456 - regression_loss: 6.1063 - classification_accuracy: 0.7130 - regression_mae: 1.9918
# Epoch 2: val_loss did not improve from 5.53073
# 788/788 [==============================] - 2s 2ms/step - loss: 6.7918 - classification_loss: 0.6473 - regression_loss: 6.1445 - classification_accuracy: 0.7119 - regression_mae: 1.9896 - val_loss: 5.9139 - val_classification_loss: 0.6214 - val_regression_loss: 5.2925 - val_classification_accuracy: 0.7045 - val_regression_mae: 1.7247
# Epoch 3/100
# 764/788 [============================>.] - ETA: 0s - loss: 6.1099 - classification_loss: 0.5876 - regression_loss: 5.5223 - classification_accuracy: 0.7500 - regression_mae: 1.8949
# Epoch 3: val_loss improved from 5.53073 to 4.58097, saving model to best_model.keras
# 788/788 [==============================] - 2s 2ms/step - loss: 6.0427 - classification_loss: 0.5886 - regression_loss: 5.4541 - classification_accuracy: 0.7487 - regression_mae: 1.8826 - val_loss: 4.5810 - val_classification_loss: 0.5490 - val_regression_loss: 4.0320 - val_classification_accuracy: 0.7386 - val_regression_mae: 1.6307
# Epoch 4/100
# 774/788 [============================>.] - ETA: 0s - loss: 5.8803 - classification_loss: 0.5634 - regression_loss: 5.3169 - classification_accuracy: 0.7455 - regression_mae: 1.8814
# Epoch 4: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 5.9229 - classification_loss: 0.5620 - regression_loss: 5.3609 - classification_accuracy: 0.7462 - regression_mae: 1.8874 - val_loss: 6.0237 - val_classification_loss: 0.5850 - val_regression_loss: 5.4387 - val_classification_accuracy: 0.7273 - val_regression_mae: 1.9204
# Epoch 5/100
# 782/788 [============================>.] - ETA: 0s - loss: 6.0867 - classification_loss: 0.5373 - regression_loss: 5.5493 - classification_accuracy: 0.7570 - regression_mae: 1.9268
# Epoch 5: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 6.0472 - classification_loss: 0.5362 - regression_loss: 5.5110 - classification_accuracy: 0.7576 - regression_mae: 1.9168 - val_loss: 4.8343 - val_classification_loss: 0.6318 - val_regression_loss: 4.2025 - val_classification_accuracy: 0.7273 - val_regression_mae: 1.6792
# Epoch 6/100
# 774/788 [============================>.] - ETA: 0s - loss: 5.9241 - classification_loss: 0.5425 - regression_loss: 5.3816 - classification_accuracy: 0.7649 - regression_mae: 1.8724
# Epoch 6: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 6.0004 - classification_loss: 0.5399 - regression_loss: 5.4604 - classification_accuracy: 0.7652 - regression_mae: 1.8816 - val_loss: 4.6228 - val_classification_loss: 0.5868 - val_regression_loss: 4.0360 - val_classification_accuracy: 0.7500 - val_regression_mae: 1.7084
# Epoch 7/100
# 774/788 [============================>.] - ETA: 0s - loss: 5.8211 - classification_loss: 0.5119 - regression_loss: 5.3092 - classification_accuracy: 0.7739 - regression_mae: 1.8481
# Epoch 7: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 5.8620 - classification_loss: 0.5210 - regression_loss: 5.3410 - classification_accuracy: 0.7716 - regression_mae: 1.8570 - val_loss: 5.0063 - val_classification_loss: 0.5301 - val_regression_loss: 4.4762 - val_classification_accuracy: 0.7614 - val_regression_mae: 1.7232
# Epoch 8/100
# 780/788 [============================>.] - ETA: 0s - loss: 5.6446 - classification_loss: 0.4795 - regression_loss: 5.1651 - classification_accuracy: 0.7923 - regression_mae: 1.8407
# Epoch 8: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 3ms/step - loss: 5.6212 - classification_loss: 0.4789 - regression_loss: 5.1423 - classification_accuracy: 0.7919 - regression_mae: 1.8364 - val_loss: 5.5057 - val_classification_loss: 0.5750 - val_regression_loss: 4.9307 - val_classification_accuracy: 0.7159 - val_regression_mae: 1.8362
# Epoch 9/100
# 765/788 [============================>.] - ETA: 0s - loss: 5.4831 - classification_loss: 0.4865 - regression_loss: 4.9967 - classification_accuracy: 0.7961 - regression_mae: 1.7883
# Epoch 9: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 5.5340 - classification_loss: 0.4946 - regression_loss: 5.0394 - classification_accuracy: 0.7931 - regression_mae: 1.7985 - val_loss: 6.6951 - val_classification_loss: 0.5020 - val_regression_loss: 6.1931 - val_classification_accuracy: 0.7955 - val_regression_mae: 2.0765
# Epoch 10/100
# 783/788 [============================>.] - ETA: 0s - loss: 5.5126 - classification_loss: 0.4743 - regression_loss: 5.0383 - classification_accuracy: 0.8097 - regression_mae: 1.7754
# Epoch 10: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 5.5062 - classification_loss: 0.4746 - regression_loss: 5.0316 - classification_accuracy: 0.8084 - regression_mae: 1.7730 - val_loss: 4.9464 - val_classification_loss: 0.5777 - val_regression_loss: 4.3687 - val_classification_accuracy: 0.7500 - val_regression_mae: 1.7637
# Epoch 11/100
# 771/788 [============================>.] - ETA: 0s - loss: 5.2767 - classification_loss: 0.4629 - regression_loss: 4.8138 - classification_accuracy: 0.7964 - regression_mae: 1.7732
# Epoch 11: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 5.2542 - classification_loss: 0.4650 - regression_loss: 4.7893 - classification_accuracy: 0.7970 - regression_mae: 1.7675 - val_loss: 4.6532 - val_classification_loss: 0.6352 - val_regression_loss: 4.0180 - val_classification_accuracy: 0.7159 - val_regression_mae: 1.6317
# Epoch 12/100
# 768/788 [============================>.] - ETA: 0s - loss: 5.2461 - classification_loss: 0.4714 - regression_loss: 4.7747 - classification_accuracy: 0.7969 - regression_mae: 1.7580
# Epoch 12: val_loss did not improve from 4.58097
# 788/788 [==============================] - 2s 2ms/step - loss: 5.2216 - classification_loss: 0.4687 - regression_loss: 4.7529 - classification_accuracy: 0.7982 - regression_mae: 1.7549 - val_loss: 5.3846 - val_classification_loss: 0.6549 - val_regression_loss: 4.7296 - val_classification_accuracy: 0.7273 - val_regression_mae: 1.8391
# Epoch 13/100
# 774/788 [============================>.] - ETA: 0s - loss: 5.1296 - classification_loss: 0.4606 - regression_loss: 4.6691 - classification_accuracy: 0.7997 - regression_mae: 1.7259
# Epoch 13: val_loss did not improve from 4.58097
# 788/788 [==============================] - 3s 3ms/step - loss: 5.1210 - classification_loss: 0.4580 - regression_loss: 4.6630 - classification_accuracy: 0.8008 - regression_mae: 1.7244 - val_loss: 5.3605 - val_classification_loss: 0.7585 - val_regression_loss: 4.6020 - val_classification_accuracy: 0.7045 - val_regression_mae: 1.7776
# Epoch 14/100
# 784/788 [============================>.] - ETA: 0s - loss: 5.2191 - classification_loss: 0.4591 - regression_loss: 4.7600 - classification_accuracy: 0.8138 - regression_mae: 1.7527
# Epoch 14: val_loss improved from 4.58097 to 4.41012, saving model to best_model.keras
# 788/788 [==============================] - 2s 2ms/step - loss: 5.2353 - classification_loss: 0.4588 - regression_loss: 4.7765 - classification_accuracy: 0.8135 - regression_mae: 1.7572 - val_loss: 4.4101 - val_classification_loss: 0.5865 - val_regression_loss: 3.8237 - val_classification_accuracy: 0.7159 - val_regression_mae: 1.6009
# Epoch 15/100
# 784/788 [============================>.] - ETA: 0s - loss: 5.1543 - classification_loss: 0.4331 - regression_loss: 4.7212 - classification_accuracy: 0.8151 - regression_mae: 1.7114
# Epoch 15: val_loss did not improve from 4.41012
# 788/788 [==============================] - 2s 2ms/step - loss: 5.1378 - classification_loss: 0.4311 - regression_loss: 4.7067 - classification_accuracy: 0.8160 - regression_mae: 1.7095 - val_loss: 4.8279 - val_classification_loss: 0.6365 - val_regression_loss: 4.1914 - val_classification_accuracy: 0.7614 - val_regression_mae: 1.7282
# Epoch 16/100
# 783/788 [============================>.] - ETA: 0s - loss: 5.0115 - classification_loss: 0.4414 - regression_loss: 4.5702 - classification_accuracy: 0.8097 - regression_mae: 1.7138
# Epoch 16: val_loss did not improve from 4.41012
# 788/788 [==============================] - 2s 2ms/step - loss: 5.0203 - classification_loss: 0.4420 - regression_loss: 4.5783 - classification_accuracy: 0.8084 - regression_mae: 1.7156 - val_loss: 4.7538 - val_classification_loss: 0.5780 - val_regression_loss: 4.1758 - val_classification_accuracy: 0.7841 - val_regression_mae: 1.6512
# Epoch 17/100
# 777/788 [============================>.] - ETA: 0s - loss: 4.8032 - classification_loss: 0.4291 - regression_loss: 4.3741 - classification_accuracy: 0.8250 - regression_mae: 1.6464
# Epoch 17: val_loss improved from 4.41012 to 4.34629, saving model to best_model.keras
# 788/788 [==============================] - 2s 2ms/step - loss: 4.7986 - classification_loss: 0.4294 - regression_loss: 4.3692 - classification_accuracy: 0.8249 - regression_mae: 1.6493 - val_loss: 4.3463 - val_classification_loss: 0.5059 - val_regression_loss: 3.8404 - val_classification_accuracy: 0.7841 - val_regression_mae: 1.6656
# Epoch 18/100
# 777/788 [============================>.] - ETA: 0s - loss: 4.6388 - classification_loss: 0.4218 - regression_loss: 4.2171 - classification_accuracy: 0.8366 - regression_mae: 1.6210
# Epoch 18: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.6412 - classification_loss: 0.4222 - regression_loss: 4.2190 - classification_accuracy: 0.8363 - regression_mae: 1.6228 - val_loss: 6.3287 - val_classification_loss: 0.6535 - val_regression_loss: 5.6752 - val_classification_accuracy: 0.7273 - val_regression_mae: 1.9671
# Epoch 19/100
# 780/788 [============================>.] - ETA: 0s - loss: 4.7820 - classification_loss: 0.4242 - regression_loss: 4.3578 - classification_accuracy: 0.8218 - regression_mae: 1.6503
# Epoch 19: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.7623 - classification_loss: 0.4209 - regression_loss: 4.3413 - classification_accuracy: 0.8236 - regression_mae: 1.6471 - val_loss: 4.3895 - val_classification_loss: 0.5944 - val_regression_loss: 3.7951 - val_classification_accuracy: 0.7614 - val_regression_mae: 1.5655
# Epoch 20/100
# 780/788 [============================>.] - ETA: 0s - loss: 4.6953 - classification_loss: 0.4186 - regression_loss: 4.2768 - classification_accuracy: 0.8244 - regression_mae: 1.6208
# Epoch 20: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.6650 - classification_loss: 0.4154 - regression_loss: 4.2496 - classification_accuracy: 0.8261 - regression_mae: 1.6148 - val_loss: 4.9008 - val_classification_loss: 0.5420 - val_regression_loss: 4.3589 - val_classification_accuracy: 0.7841 - val_regression_mae: 1.6893
# Epoch 21/100
# 769/788 [============================>.] - ETA: 0s - loss: 4.5567 - classification_loss: 0.3917 - regression_loss: 4.1650 - classification_accuracy: 0.8309 - regression_mae: 1.6137
# Epoch 21: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 3ms/step - loss: 4.6232 - classification_loss: 0.3856 - regression_loss: 4.2376 - classification_accuracy: 0.8338 - regression_mae: 1.6289 - val_loss: 5.6174 - val_classification_loss: 0.6870 - val_regression_loss: 4.9304 - val_classification_accuracy: 0.7500 - val_regression_mae: 1.8368
# Epoch 22/100
# 766/788 [============================>.] - ETA: 0s - loss: 4.4802 - classification_loss: 0.3817 - regression_loss: 4.0985 - classification_accuracy: 0.8460 - regression_mae: 1.5872
# Epoch 22: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.5497 - classification_loss: 0.3822 - regression_loss: 4.1676 - classification_accuracy: 0.8477 - regression_mae: 1.5979 - val_loss: 4.8125 - val_classification_loss: 0.6445 - val_regression_loss: 4.1680 - val_classification_accuracy: 0.7386 - val_regression_mae: 1.7105
# Epoch 23/100
# 763/788 [============================>.] - ETA: 0s - loss: 4.4865 - classification_loss: 0.3828 - regression_loss: 4.1037 - classification_accuracy: 0.8401 - regression_mae: 1.6018
# Epoch 23: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.5549 - classification_loss: 0.3890 - regression_loss: 4.1659 - classification_accuracy: 0.8388 - regression_mae: 1.6157 - val_loss: 5.1623 - val_classification_loss: 0.6425 - val_regression_loss: 4.5198 - val_classification_accuracy: 0.7159 - val_regression_mae: 1.7634
# Epoch 24/100
# 785/788 [============================>.] - ETA: 0s - loss: 4.7050 - classification_loss: 0.3788 - regression_loss: 4.3262 - classification_accuracy: 0.8459 - regression_mae: 1.6151
# Epoch 24: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 3ms/step - loss: 4.6950 - classification_loss: 0.3776 - regression_loss: 4.3174 - classification_accuracy: 0.8464 - regression_mae: 1.6129 - val_loss: 5.6049 - val_classification_loss: 0.5624 - val_regression_loss: 5.0425 - val_classification_accuracy: 0.7386 - val_regression_mae: 1.8580
# Epoch 25/100
# 777/788 [============================>.] - ETA: 0s - loss: 4.5364 - classification_loss: 0.3641 - regression_loss: 4.1723 - classification_accuracy: 0.8546 - regression_mae: 1.6037
# Epoch 25: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.5455 - classification_loss: 0.3738 - regression_loss: 4.1717 - classification_accuracy: 0.8503 - regression_mae: 1.6044 - val_loss: 4.7262 - val_classification_loss: 0.5519 - val_regression_loss: 4.1743 - val_classification_accuracy: 0.7727 - val_regression_mae: 1.7132
# Epoch 26/100
# 776/788 [============================>.] - ETA: 0s - loss: 4.3680 - classification_loss: 0.3815 - regression_loss: 3.9865 - classification_accuracy: 0.8351 - regression_mae: 1.5615
# Epoch 26: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 3ms/step - loss: 4.3438 - classification_loss: 0.3804 - regression_loss: 3.9634 - classification_accuracy: 0.8350 - regression_mae: 1.5573 - val_loss: 5.0095 - val_classification_loss: 0.5733 - val_regression_loss: 4.4362 - val_classification_accuracy: 0.8068 - val_regression_mae: 1.7593
# Epoch 27/100
# 784/788 [============================>.] - ETA: 0s - loss: 4.3343 - classification_loss: 0.3650 - regression_loss: 3.9693 - classification_accuracy: 0.8431 - regression_mae: 1.5548
# Epoch 27: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 3ms/step - loss: 4.3181 - classification_loss: 0.3644 - regression_loss: 3.9536 - classification_accuracy: 0.8426 - regression_mae: 1.5513 - val_loss: 4.8087 - val_classification_loss: 0.5263 - val_regression_loss: 4.2824 - val_classification_accuracy: 0.7500 - val_regression_mae: 1.7188
# Epoch 28/100
# 775/788 [============================>.] - ETA: 0s - loss: 4.2292 - classification_loss: 0.3597 - regression_loss: 3.8694 - classification_accuracy: 0.8542 - regression_mae: 1.5421
# Epoch 28: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.2768 - classification_loss: 0.3689 - regression_loss: 3.9078 - classification_accuracy: 0.8503 - regression_mae: 1.5514 - val_loss: 5.0483 - val_classification_loss: 0.5744 - val_regression_loss: 4.4739 - val_classification_accuracy: 0.7273 - val_regression_mae: 1.7787
# Epoch 29/100
# 774/788 [============================>.] - ETA: 0s - loss: 4.1908 - classification_loss: 0.3592 - regression_loss: 3.8317 - classification_accuracy: 0.8437 - regression_mae: 1.5432
# Epoch 29: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.2355 - classification_loss: 0.3611 - regression_loss: 3.8744 - classification_accuracy: 0.8414 - regression_mae: 1.5483 - val_loss: 5.1895 - val_classification_loss: 0.5883 - val_regression_loss: 4.6012 - val_classification_accuracy: 0.7500 - val_regression_mae: 1.7805
# Epoch 30/100
# 781/788 [============================>.] - ETA: 0s - loss: 4.3557 - classification_loss: 0.3444 - regression_loss: 4.0113 - classification_accuracy: 0.8604 - regression_mae: 1.5544
# Epoch 30: val_loss did not improve from 4.34629
# 788/788 [==============================] - 3s 3ms/step - loss: 4.3699 - classification_loss: 0.3424 - regression_loss: 4.0274 - classification_accuracy: 0.8617 - regression_mae: 1.5581 - val_loss: 4.9360 - val_classification_loss: 0.6903 - val_regression_loss: 4.2457 - val_classification_accuracy: 0.6932 - val_regression_mae: 1.7130
# Epoch 31/100
# 777/788 [============================>.] - ETA: 0s - loss: 4.2327 - classification_loss: 0.3461 - regression_loss: 3.8866 - classification_accuracy: 0.8520 - regression_mae: 1.5249
# Epoch 31: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.2187 - classification_loss: 0.3457 - regression_loss: 3.8729 - classification_accuracy: 0.8515 - regression_mae: 1.5225 - val_loss: 5.0664 - val_classification_loss: 0.6072 - val_regression_loss: 4.4592 - val_classification_accuracy: 0.7500 - val_regression_mae: 1.7372
# Epoch 32/100
# 788/788 [==============================] - ETA: 0s - loss: 4.0466 - classification_loss: 0.3597 - regression_loss: 3.6869 - classification_accuracy: 0.8490 - regression_mae: 1.4987
# Epoch 32: val_loss did not improve from 4.34629
# 788/788 [==============================] - 2s 2ms/step - loss: 4.0466 - classification_loss: 0.3597 - regression_loss: 3.6869 - classification_accuracy: 0.8490 - regression_mae: 1.4987 - val_loss: 5.4214 - val_classification_loss: 0.5863 - val_regression_loss: 4.8351 - val_classification_accuracy: 0.7955 - val_regression_mae: 1.8064

# %%
# 테스트 데이터 평가
from sklearn.metrics import confusion_matrix
results = model.evaluate(
    X_test,
    {'classification': y_test_classification, 'regression': y_test_regression})

print(f"Classification Accuracy: {results[3]}")
print(f"Regression MAE: {results[4]}")
# Out:
# 3/3 [==============================] - 0s 3ms/step - loss: 4.3463 - classification_loss: 0.5059 - regression_loss: 3.8404 - classification_accuracy: 0.7841 - regression_mae: 1.6656
# Classification Accuracy: 0.7840909361839294
# Regression MAE: 1.665557861328125

# %%
import matplotlib.pyplot as plt

# 'history'는 model.fit()의 반환값입니다.
# 분류 및 회귀 손실 데이터 추출
classification_loss = history.history['classification_loss']
regression_loss = history.history['regression_loss']
classification_val_loss = history.history['val_classification_loss']
regression_val_loss = history.history['val_regression_loss']

# 그래프 크기 설정
plt.figure(figsize=(12, 6))

# 분류 손실 그래프
plt.subplot(1, 2, 1)
plt.plot(classification_loss, label='Train Classification Loss')
plt.plot(classification_val_loss, label='Validation Classification Loss')
plt.title('Classification Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 회귀 손실 그래프
plt.subplot(1, 2, 2)
plt.plot(regression_loss, label='Train Regression Loss')
plt.plot(regression_val_loss, label='Validation Regression Loss')
plt.title('Regression Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 레이아웃 조정 및 출력
plt.tight_layout()
plt.show()
