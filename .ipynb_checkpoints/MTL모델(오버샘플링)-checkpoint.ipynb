# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
path = "/Users/hongjonghyeok/Downloads/데이터 전처리 과정/최종통합본.csv"
df = pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'Latitude', 'Longitude', 'Supply_type',
#        'Applicant_type', 'Units', 'Gender', 'Shared', 'Cutline_rate',
#        'Cutline_score', 'Year', 'Quarter', 'Applied_type', 'Counts_daiso',
#        'Counts_supermarket', 'Counts_laundry', 'Counts_pharmacy',
#        'Counts_cafe', 'Counts_convstore', 'Counts_station', 'Infra_score',
#        'people', 'Rate1', 'Rate2', 'Rate3'],
#       dtype='object')

# %%
df.dropna(axis=0, inplace=True)

# %%
# 주요 입력 변수 및 타겟 변수 선택
features = ['Supply_type', 'Units', 'Gender', 'Year',
            'Quarter', 'Rate1', 'Rate2', 'Rate3', 'Applicant_type',
           'Applied_type', 'Shared', 'Cutline_score', 'Counts_daiso',
       'Counts_supermarket', 'Counts_laundry', 'Counts_pharmacy',
       'Counts_cafe', 'Counts_convstore', 'Counts_station', 'Infra_score']
X = df[features]
y = df['Cutline_rate']  # 분류 타겟

# %%
X.shape
# Out:
# (876, 20)

# %%
# 범주형 변수 인코딩
X['Supply_type'] = LabelEncoder().fit_transform(X['Supply_type'])
X['Applicant_type'] = LabelEncoder().fit_transform(X['Applicant_type'])
X['Gender'] = LabelEncoder().fit_transform(X['Gender'])
X['Applied_type'] = LabelEncoder().fit_transform(X['Applied_type'])
X['Shared'] = LabelEncoder().fit_transform(X['Shared'])
X['Year'] = LabelEncoder().fit_transform(X['Year'])
X['Quarter'] = LabelEncoder().fit_transform(X['Quarter'])
# Out:
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Supply_type'] = LabelEncoder().fit_transform(X['Supply_type'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Applicant_type'] = LabelEncoder().fit_transform(X['Applicant_type'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Gender'] = LabelEncoder().fit_transform(X['Gender'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Applied_type'] = LabelEncoder().fit_transform(X['Applied_type'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Shared'] = LabelEncoder().fit_transform(X['Shared'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Year'] = LabelEncoder().fit_transform(X['Year'])
# /var/folders/4g/1y1rn_456xx_f85fqpq2pl0m0000gn/T/ipykernel_67357/586852210.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Quarter'] = LabelEncoder().fit_transform(X['Quarter'])

# %%
from imblearn.over_sampling import ADASYN
from collections import Counter

# ADASYN 적용
adasyn = ADASYN(random_state=42)
X_s, y_s = adasyn.fit_resample(X, y)

# 결과 확인
print("오버샘플링 전 클래스 분포:", Counter(y))
print("오버샘플링 후 클래스 분포:", Counter(y_s))
# Out:
# 오버샘플링 전 클래스 분포: Counter({1: 573, 2: 269, 3: 34})
# 오버샘플링 후 클래스 분포: Counter({1: 573, 3: 570, 2: 529})

# %%
X = X_s.copy()
y_classification = y_s.copy()  # 분류 타겟
y_regression = X_s['Cutline_score']    # 회귀 타겟

# %%
X.shape
# Out:
# (1672, 20)

# %%
# 데이터 분리
X_train, X_test, y_train_classification, y_test_classification, y_train_regression, y_test_regression = train_test_split(X, y_classification, y_regression, test_size=0.1, random_state=42)

# %% [markdown]
# # 데이터 스케일링
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
# 데이터 스케일링
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 레이블 값 변환 (1 → 0, 2 → 1, 3 → 2)
y_train_classification = y_train_classification - 1
y_test_classification = y_test_classification - 1

# %%
X_train.shape
# Out:
# (1504, 20)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 입력 레이어
il = Input(shape=(X_train.shape[1],))

# 공유 레이어
dl = Dense(512, activation='relu')(il)
dl = Dense(256, activation='relu')(dl)
dl = Dense(256, activation='relu')(dl)
dl = Dense(128, activation='relu')(dl)

# 분류 헤드 (cutline_rate)
classification_head = Dense(3, activation='softmax', name='classification')(dl)

# 회귀 헤드 (cutline_score)
regression_head = Dense(1, activation='relu', name='regression')(dl)

# %%
# 모델 정의
model = Model(inputs=il, outputs=[classification_head, regression_head])

# %%
# 모델 컴파일
model.compile(
    optimizer='adam',
    loss={'classification': 'sparse_categorical_crossentropy', 'regression': 'mse'},
    metrics={'classification': 'accuracy', 'regression': 'mae'})

# %%
# EarlyStopping 콜백 정의
es = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 모니터링
    patience=15,              # 개선되지 않는 에포크를 15번 허용
    restore_best_weights=True) # 가장 좋은 가중치를 복원

# %%
checkpoint_path = 'best_model.keras'
mc = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True)

# %%
# 모델 학습
history = model.fit(
    X_train,
    {'classification': y_train_classification, 'regression': y_train_regression},
    validation_data=(X_test, {'classification': y_test_classification, 'regression': y_test_regression}),
    epochs=100,               # 최대 에포크 수
    batch_size=1,
    callbacks=[es, mc]) # EarlyStopping 콜백 추가
# Out:
# Epoch 1/100
# 1493/1504 [============================>.] - ETA: 0s - loss: 2.3161 - classification_loss: 0.6885 - regression_loss: 1.6276 - classification_accuracy: 0.6631 - regression_mae: 0.7050
# Epoch 1: val_loss improved from inf to 0.63320, saving model to best_model.keras
# 1504/1504 [==============================] - 1s 842us/step - loss: 2.3034 - classification_loss: 0.6873 - regression_loss: 1.6161 - classification_accuracy: 0.6642 - regression_mae: 0.7011 - val_loss: 0.6332 - val_classification_loss: 0.4817 - val_regression_loss: 0.1515 - val_classification_accuracy: 0.8036 - val_regression_mae: 0.2966
# Epoch 2/100
# 1502/1504 [============================>.] - ETA: 0s - loss: 0.7764 - classification_loss: 0.4738 - regression_loss: 0.3027 - classification_accuracy: 0.7863 - regression_mae: 0.3824
# Epoch 2: val_loss improved from 0.63320 to 0.62167, saving model to best_model.keras
# 1504/1504 [==============================] - 1s 796us/step - loss: 0.7756 - classification_loss: 0.4732 - regression_loss: 0.3023 - classification_accuracy: 0.7866 - regression_mae: 0.3822 - val_loss: 0.6217 - val_classification_loss: 0.4258 - val_regression_loss: 0.1959 - val_classification_accuracy: 0.8095 - val_regression_mae: 0.3363
# Epoch 3/100
# 1475/1504 [============================>.] - ETA: 0s - loss: 0.6867 - classification_loss: 0.3996 - regression_loss: 0.2871 - classification_accuracy: 0.8231 - regression_mae: 0.3836
# Epoch 3: val_loss improved from 0.62167 to 0.45931, saving model to best_model.keras
# 1504/1504 [==============================] - 1s 835us/step - loss: 0.6833 - classification_loss: 0.3976 - regression_loss: 0.2857 - classification_accuracy: 0.8245 - regression_mae: 0.3831 - val_loss: 0.4593 - val_classification_loss: 0.2964 - val_regression_loss: 0.1629 - val_classification_accuracy: 0.8929 - val_regression_mae: 0.3123
# Epoch 4/100
# 1448/1504 [===========================>..] - ETA: 0s - loss: 0.5553 - classification_loss: 0.3545 - regression_loss: 0.2008 - classification_accuracy: 0.8522 - regression_mae: 0.3169
# Epoch 4: val_loss did not improve from 0.45931
# 1504/1504 [==============================] - 1s 809us/step - loss: 0.5553 - classification_loss: 0.3588 - regression_loss: 0.1964 - classification_accuracy: 0.8511 - regression_mae: 0.3134 - val_loss: 0.4637 - val_classification_loss: 0.4114 - val_regression_loss: 0.0523 - val_classification_accuracy: 0.8155 - val_regression_mae: 0.1691
# Epoch 5/100
# 1451/1504 [===========================>..] - ETA: 0s - loss: 0.5816 - classification_loss: 0.3397 - regression_loss: 0.2419 - classification_accuracy: 0.8608 - regression_mae: 0.3193
# Epoch 5: val_loss did not improve from 0.45931
# 1504/1504 [==============================] - 1s 804us/step - loss: 0.5838 - classification_loss: 0.3404 - regression_loss: 0.2434 - classification_accuracy: 0.8584 - regression_mae: 0.3218 - val_loss: 0.5694 - val_classification_loss: 0.4585 - val_regression_loss: 0.1108 - val_classification_accuracy: 0.8155 - val_regression_mae: 0.2630
# Epoch 6/100
# 1485/1504 [============================>.] - ETA: 0s - loss: 0.4449 - classification_loss: 0.3159 - regression_loss: 0.1290 - classification_accuracy: 0.8707 - regression_mae: 0.2462
# Epoch 6: val_loss did not improve from 0.45931
# 1504/1504 [==============================] - 1s 856us/step - loss: 0.4502 - classification_loss: 0.3225 - regression_loss: 0.1278 - classification_accuracy: 0.8697 - regression_mae: 0.2448 - val_loss: 0.5737 - val_classification_loss: 0.4958 - val_regression_loss: 0.0779 - val_classification_accuracy: 0.8095 - val_regression_mae: 0.2169
# Epoch 7/100
# 1437/1504 [===========================>..] - ETA: 0s - loss: 0.3971 - classification_loss: 0.2758 - regression_loss: 0.1213 - classification_accuracy: 0.8887 - regression_mae: 0.2512
# Epoch 7: val_loss improved from 0.45931 to 0.38820, saving model to best_model.keras
# 1504/1504 [==============================] - 1s 820us/step - loss: 0.4073 - classification_loss: 0.2766 - regression_loss: 0.1308 - classification_accuracy: 0.8883 - regression_mae: 0.2578 - val_loss: 0.3882 - val_classification_loss: 0.2691 - val_regression_loss: 0.1191 - val_classification_accuracy: 0.8929 - val_regression_mae: 0.2499
# Epoch 8/100
# 1465/1504 [============================>.] - ETA: 0s - loss: 0.4207 - classification_loss: 0.2464 - regression_loss: 0.1742 - classification_accuracy: 0.8874 - regression_mae: 0.2643
# Epoch 8: val_loss did not improve from 0.38820
# 1504/1504 [==============================] - 1s 798us/step - loss: 0.4205 - classification_loss: 0.2493 - regression_loss: 0.1712 - classification_accuracy: 0.8876 - regression_mae: 0.2618 - val_loss: 0.4542 - val_classification_loss: 0.4195 - val_regression_loss: 0.0346 - val_classification_accuracy: 0.8214 - val_regression_mae: 0.1358
# Epoch 9/100
# 1460/1504 [============================>.] - ETA: 0s - loss: 0.3630 - classification_loss: 0.2493 - regression_loss: 0.1137 - classification_accuracy: 0.9089 - regression_mae: 0.2250
# Epoch 9: val_loss improved from 0.38820 to 0.27149, saving model to best_model.keras
# 1504/1504 [==============================] - 1s
- val_classification_accuracy: 0.9226 - val_regression_mae: 0.0995
# Epoch 28/100
# 1443/1504 [===========================>..] - ETA: 0s - loss: 0.1432 - classification_loss: 0.1005 - regression_loss: 0.0427 - classification_accuracy: 0.9709 - regression_mae: 0.1417
# Epoch 28: val_loss improved from 0.20727 to 0.19588, saving model to best_model.keras
# 1504/1504 [==============================] - 1s 818us/step - loss: 0.1490 - classification_loss: 0.1071 - regression_loss: 0.0419 - classification_accuracy: 0.9681 - regression_mae: 0.1405 - val_loss: 0.1959 - val_classification_loss: 0.1713 - val_regression_loss: 0.0245 - val_classification_accuracy: 0.9464 - val_regression_mae: 0.1131
# Epoch 29/100
# 1449/1504 [===========================>..] - ETA: 0s - loss: 0.1506 - classification_loss: 0.1000 - regression_loss: 0.0506 - classification_accuracy: 0.9717 - regression_mae: 0.1468
# Epoch 29: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 807us/step - loss: 0.1540 - classification_loss: 0.1029 - regression_loss: 0.0511 - classification_accuracy: 0.9707 - regression_mae: 0.1484 - val_loss: 0.2693 - val_classification_loss: 0.2159 - val_regression_loss: 0.0534 - val_classification_accuracy: 0.9226 - val_regression_mae: 0.1906
# Epoch 30/100
# 1496/1504 [============================>.] - ETA: 0s - loss: 0.1157 - classification_loss: 0.0819 - regression_loss: 0.0338 - classification_accuracy: 0.9706 - regression_mae: 0.1255
# Epoch 30: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 816us/step - loss: 0.1161 - classification_loss: 0.0818 - regression_loss: 0.0343 - classification_accuracy: 0.9707 - regression_mae: 0.1261 - val_loss: 0.3196 - val_classification_loss: 0.2669 - val_regression_loss: 0.0526 - val_classification_accuracy: 0.9286 - val_regression_mae: 0.1770
# Epoch 31/100
# 1483/1504 [============================>.] - ETA: 0s - loss: 0.1327 - classification_loss: 0.0925 - regression_loss: 0.0402 - classification_accuracy: 0.9744 - regression_mae: 0.1344
# Epoch 31: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 823us/step - loss: 0.1351 - classification_loss: 0.0948 - regression_loss: 0.0403 - classification_accuracy: 0.9734 - regression_mae: 0.1344 - val_loss: 0.2408 - val_classification_loss: 0.1951 - val_regression_loss: 0.0457 - val_classification_accuracy: 0.9226 - val_regression_mae: 0.1628
# Epoch 32/100
# 1443/1504 [===========================>..] - ETA: 0s - loss: 0.1368 - classification_loss: 0.0839 - regression_loss: 0.0529 - classification_accuracy: 0.9723 - regression_mae: 0.1561
# Epoch 32: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 810us/step - loss: 0.1343 - classification_loss: 0.0827 - regression_loss: 0.0516 - classification_accuracy: 0.9721 - regression_mae: 0.1541 - val_loss: 0.3746 - val_classification_loss: 0.3594 - val_regression_loss: 0.0152 - val_classification_accuracy: 0.9226 - val_regression_mae: 0.0881
# Epoch 33/100
# 1502/1504 [============================>.] - ETA: 0s - loss: 0.1292 - classification_loss: 0.0915 - regression_loss: 0.0377 - classification_accuracy: 0.9680 - regression_mae: 0.1307
# Epoch 33: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 813us/step - loss: 0.1291 - classification_loss: 0.0914 - regression_loss: 0.0377 - classification_accuracy: 0.9681 - regression_mae: 0.1308 - val_loss: 0.2852 - val_classification_loss: 0.2486 - val_regression_loss: 0.0365 - val_classification_accuracy: 0.9345 - val_regression_mae: 0.1175
# Epoch 34/100
# 1440/1504 [===========================>..] - ETA: 0s - loss: 0.0974 - classification_loss: 0.0672 - regression_loss: 0.0303 - classification_accuracy: 0.9764 - regression_mae: 0.1202
# Epoch 34: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s
val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 810us/step - loss: 0.1542 - classification_loss: 0.1075 - regression_loss: 0.0467 - classification_accuracy: 0.9674 - regression_mae: 0.1446 - val_loss: 0.3203 - val_classification_loss: 0.2981 - val_regression_loss: 0.0222 - val_classification_accuracy: 0.9107 - val_regression_mae: 0.0947
# Epoch 41/100
# 1494/1504 [============================>.] - ETA: 0s - loss: 0.0909 - classification_loss: 0.0613 - regression_loss: 0.0295 - classification_accuracy: 0.9799 - regression_mae: 0.1164
# Epoch 41: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 803us/step - loss: 0.0903 - classification_loss: 0.0609 - regression_loss: 0.0294 - classification_accuracy: 0.9801 - regression_mae: 0.1161 - val_loss: 0.3270 - val_classification_loss: 0.3033 - val_regression_loss: 0.0237 - val_classification_accuracy: 0.9286 - val_regression_mae: 0.1217
# Epoch 42/100
# 1500/1504 [============================>.] - ETA: 0s - loss: 0.1100 - classification_loss: 0.0755 - regression_loss: 0.0345 - classification_accuracy: 0.9793 - regression_mae: 0.1235
# Epoch 42: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 815us/step - loss: 0.1098 - classification_loss: 0.0754 - regression_loss: 0.0344 - classification_accuracy: 0.9794 - regression_mae: 0.1233 - val_loss: 0.2615 - val_classification_loss: 0.2386 - val_regression_loss: 0.0229 - val_classification_accuracy: 0.9405 - val_regression_mae: 0.0931
# Epoch 43/100
# 1446/1504 [===========================>..] - ETA: 0s - loss: 0.0732 - classification_loss: 0.0398 - regression_loss: 0.0334 - classification_accuracy: 0.9882 - regression_mae: 0.1200
# Epoch 43: val_loss did not improve from 0.19588
# 1504/1504 [==============================] - 1s 841us/step - loss: 0.0732 - classification_loss: 0.0399 - regression_loss: 0.0333 - classification_accuracy: 0.9880 - regression_mae: 0.1193 - val_loss: 0.3272 - val_classification_loss: 0.3140 - val_regression_loss: 0.0132 - val_classification_accuracy: 0.9405 - val_regression_mae: 0.0800

# %%
# 테스트 데이터 평가
from sklearn.metrics import confusion_matrix
results = model.evaluate(
    X_test,
    {'classification': y_test_classification, 'regression': y_test_regression})

print(f"Classification Accuracy: {results[3]}")
print(f"Regression MAE: {results[4]}")
# Out:
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1959 - classification_loss: 0.1713 - regression_loss: 0.0245 - classification_accuracy: 0.9464 - regression_mae: 0.1131
# Classification Accuracy: 0.9464285969734192
# Regression MAE: 0.11309654265642166

# %%
import matplotlib.pyplot as plt

# 'history'는 model.fit()의 반환값입니다.
# 분류 및 회귀 손실 데이터 추출
classification_loss = history.history['classification_loss']
regression_loss = history.history['regression_loss']
classification_val_loss = history.history['val_classification_loss']
regression_val_loss = history.history['val_regression_loss']

# 그래프 크기 설정
plt.figure(figsize=(12, 6))

# 분류 손실 그래프
plt.subplot(1, 2, 1)
plt.plot(classification_loss, label='Train Classification Loss')
plt.plot(classification_val_loss, label='Validation Classification Loss')
plt.title('Classification Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 회귀 손실 그래프
plt.subplot(1, 2, 2)
plt.plot(regression_loss, label='Train Regression Loss')
plt.plot(regression_val_loss, label='Validation Regression Loss')
plt.title('Regression Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 레이아웃 조정 및 출력
plt.tight_layout()
plt.show()
